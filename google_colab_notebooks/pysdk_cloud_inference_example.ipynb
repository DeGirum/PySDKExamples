# %%
# !python3 -m pip install --quiet degirum

# %%
import degirum as dg
zoo=dg.connect(dg.CLOUD, 'https://cs.degirum.com/degirum/public', cloud_token)
model=zoo.load_model('mobilenet_v2_ssd_coco--300x300_quant_n2x_orca1_1')
model.image_backend='pil'
res=model('https://raw.githubusercontent.com/DeGirum/PySDKExamples/main/images/TwoCats.jpg')
res.image_overlay
