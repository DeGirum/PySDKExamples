# %%
# !python3 -m pip install --quiet degirum
# !curl -sL https://tinyurl.com/j9p7ekss > ThreeCats.jpg

# %%
import degirum as dg
zoo = dg.connect(dg.CLOUD, zoo_url="https://cs.degirum.com/degirum/ultralytics", token="<insert token here>")
model = zoo.load_model("yolov8n_silu_coco--640x640_quant_tflite_edgetpu_1")
res = model("ThreeCats.jpg")
res.image_overlay
# Out:
# <PIL.Image.Image image mode=RGB size=612x344>

# %%
zoo.list_models()
# Out:
# ['yolov5nu_relu6_car--640x640_float_openvino_cpu_1',
#  'yolov5nu_relu6_car--640x640_float_tflite_cpu_1',
#  'yolov5nu_relu6_car--640x640_quant_tflite_cpu_1',
#  'yolov5nu_relu6_car--640x640_quant_tflite_edgetpu_1',
#  'yolov5nu_relu6_coco--640x640_float_openvino_cpu_1',
#  'yolov5nu_relu6_coco--640x640_float_tflite_cpu_1',
#  'yolov5nu_relu6_coco--640x640_quant_tflite_cpu_1',
#  'yolov5nu_relu6_coco--640x640_quant_tflite_edgetpu_1',
#  'yolov5nu_relu6_face--640x640_float_openvino_cpu_1',
#  'yolov5nu_relu6_face--640x640_float_tflite_cpu_1',
#  'yolov5nu_relu6_face--640x640_quant_tflite_cpu_1',
#  'yolov5nu_relu6_face--640x640_quant_tflite_edgetpu_1',
#  'yolov5nu_relu6_hand--640x640_float_openvino_cpu_1',
#  'yolov5nu_relu6_hand--640x640_float_tflite_cpu_1',
#  'yolov5nu_relu6_hand--640x640_quant_tflite_cpu_1',
#  'yolov5nu_relu6_hand--640x640_quant_tflite_edgetpu_1',
#  'yolov5nu_relu6_lp--640x640_float_openvino_cpu_1',
#  'yolov5nu_relu6_lp--640x640_float_tflite_cpu_1',
#  'yolov5nu_relu6_lp--640x640_quant_tflite_cpu_1',
#  'yolov5nu_relu6_lp--640x640_quant_tflite_edgetpu_1',
#  'yolov5nu_silu_car--640x640_float_openvino_cpu_1',
#  'yolov5nu_silu_car--640x640_float_tflite_cpu_1',
#  'yolov5nu_silu_car--640x640_quant_tflite_cpu_1',
#  'yolov5nu_silu_car--640x640_quant_tflite_edgetpu_1',
#  'yolov5nu_silu_coco--640x640_float_openvino_cpu_1',
#  'yolov5nu_silu_coco--640x640_float_tflite_cpu_1',
#  'yolov5nu_silu_coco--640x640_quant_tflite_cpu_1',
#  'yolov5nu_silu_coco--640x640_quant_tflite_edgetpu_1',
#  'yolov5nu_silu_face--640x640_float_openvino_cpu_1',
#  'yolov5nu_silu_face--640x640_float_tflite_cpu_1',
#  'yolov5nu_silu_face--640x640_quant_tflite_cpu_1',
#  'yolov5nu_silu_face--640x640_quant_tflite_edgetpu_1',
#  'yolov5nu_silu_hand--640x640_float_openvino_cpu_1',
#  'yolov5nu_silu_hand--640x640_float_tflite_cpu_1',
#  'yolov5nu_silu_hand--640x640_quant_tflite_cpu_1',
#  'yolov5nu_silu_hand--640x640_quant_tflite_edgetpu_1',
#  'yolov5nu_silu_lp--640x640_float_openvino_cpu_1',
#  'yolov5nu_silu_lp--640x640_float_tflite_cpu_1',
#  'yolov5nu_silu_lp--640x640_quant_tflite_cpu_1',
#  'yolov5nu_silu_lp--640x640_quant_tflite_edgetpu_1',
#  'yolov5su_relu6_car--640x640_float_openvino_cpu_1',
#  'yolov5su_relu6_car--640x640_float_tflite_cpu_1',
#  'yolov5su_relu6_car--640x640_quant_tflite_cpu_1',
#  'yolov5su_relu6_car--640x640_quant_tflite_edgetpu_1',
#  'yolov5su_relu6_face--640x640_float_openvino_cpu_1',
#  'yolov5su_relu6_face--640x640_float_tflite_cpu_1',
#  'yolov5su_relu6_face--640x640_quant_tflite_cpu_1',
#  'yolov5su_relu6_face--640x640_quant_tflite_edgetpu_1',
#  'yolov5su_relu6_hand--640x640_float_openvino_cpu_1',
#  'yolov5su_relu6_hand--640x640_float_tflite_cpu_1',
#  'yolov5su_relu6_hand--640x640_quant_tflite_cpu_1',
#  'yolov5su_relu6_hand--640x640_quant_tflite_edgetpu_1',
#  'yolov5su_relu6_lp--640x640_float_openvino_cpu_1',
#  'yolov5su_relu6_lp--640x640_float_tflite_cpu_1',
#  'yolov5su_relu6_lp--640x640_quant_tflite_cpu_1',
#  'yolov5su_relu6_lp--640x640_quant_tflite_edgetpu_1',
#  'yolov5su_silu_car--640x640_float_openvino_cpu_1',
#  'yolov5su_silu_car--640x640_float_tflite_cpu_1',
#  'yolov5su_silu_car--640x640_quant_tflite_cpu_1',
#  'yolov5su_silu_car--640x640_quant_tflite_edgetpu_1',
#  'yolov5su_silu_coco--640x640_float_openvino_cpu_1',
#  'yolov5su_silu_coco--640x640_float_tflite_cpu_1',
#  'yolov5su_silu_coco--640x640_quant_tflite_cpu_1',
#  'yolov5su_silu_coco--640x640_quant_tflite_edgetpu_1',
#  'yolov5su_silu_face--640x640_float_openvino_cpu_1',
#  'yolov5su_silu_face--640x640_float_tflite_cpu_1',
#  'yolov5su_silu_face--640x640_quant_tflite_cpu_1',
#  'yolov5su_silu_face--640x640_quant_tflite_edgetpu_1',
#  'yolov5su_silu_hand--640x640_float_openvino_cpu_1',
#  'yolov5su_silu_hand--640x640_float_tflite_cpu_1',
#  'yolov5su_silu_hand--640x640_quant_tflite_cpu_1',
#  'yolov5su_silu_hand--640x640_quant_tflite_edgetpu_1',
#  'yolov5su_silu_lp--640x640_float_openvino_cpu_1',
#  'yolov5su_silu_lp--640x640_float_tflite_cpu_1',
#  'yolov5su_silu_lp--640x640_quant_tflite_cpu_1',
#  'yolov5su_silu_lp--640x640_quant_tflite_edgetpu_1',
#  'yolov8n_relu6_car--640x640_float_openvino_cpu_1',
#  'yolov8n_relu6_car--640x640_float_tflite_cpu_1',
#  'yolov8n_relu6_car--640x640_quant_tflite_cpu_1',
#  'yolov8n_relu6_car--640x640_quant_tflite_edgetpu_1',
#  'yolov8n_relu6_coco--640x640_float_openvino_cpu_1',
#  'yolov8n_relu6_coco--640x640_float_tflite_cpu_1',
#  'yolov8n_relu6_coco--640x640_quant_tflite_cpu_1',
#  'yolov8n_relu6_coco--640x640_quant_tflite_edgetpu_1',
#  'yolov8n_relu6_face--640x640_float_openvino_cpu_1',
#  'yolov8n_relu6_face--640x640_float_tflite_cpu_1',
#  'yolov8n_relu6_face--640x640_quant_tflite_cpu_1',
#  'yolov8n_relu6_face--640x640_quant_tflite_edgetpu_1',
#  'yolov8n_relu6_hand--640x640_float_openvino_cpu_1',
#  'yolov8n_relu6_hand--640x640_float_tflite_cpu_1',
#  'yolov8n_relu6_hand--640x640_quant_tflite_cpu_1',
#  'yolov8n_relu6_hand--640x640_quant_tflite_edgetpu_1',
#  'yolov8n_relu6_lp--640x640_float_openvino_cpu_1',
#  'yolov8n_relu6_lp--640x640_float_tflite_cpu_1',
#  'yolov8n_relu6_lp--640x640_quant_tflite_cpu_1',
#  'yolov8n_relu6_lp--640x640_quant_tflite_edgetpu_1',
#  'yolov8n_silu_car--640x640_float_openvino_cpu_1',
#  'yolov8n_silu_car--640x640_float_tflite_cpu_1',
#  'yolov8n_silu_car--640x640_quant_tflite_cpu_1',
#  'yolov8n_silu_car--640x640_quant_tflite_edgetpu_1',
#  'yolov8n_silu_coco--640x640_float_openvino_cpu_1',
#  'yolov8n_silu_coco--640x640_float_tflite_cpu_1',
#  'yolov8n_silu_coco--640x640_quant_tflite_cpu_1',
#  'yolov8n_silu_coco--640x640_quant_tflite_edgetpu_1',
#  'yolov8n_silu_face--640x640_float_openvino_cpu_1',
#  'yolov8n_silu_face--640x640_float_tflite_cpu_1',
#  'yolov8n_silu_face--640x640_quant_tflite_cpu_1',
#  'yolov8n_silu_face--640x640_quant_tflite_edgetpu_1',
#  'yolov8n_silu_hand--640x640_float_openvino_cpu_1',
#  'yolov8n_silu_hand--640x640_float_tflite_cpu_1',
#  'yolov8n_silu_hand--640x640_quant_tflite_cpu_1',
#  'yolov8n_silu_hand--640x640_quant_tflite_edgetpu_1',
#  'yolov8n_silu_lp--640x640_float_openvino_cpu_1',
#  'yolov8n_silu_lp--640x640_float_tflite_cpu_1',
#  'yolov8n_silu_lp--640x640_quant_tflite_cpu_1',
#  'yolov8n_silu_lp--640x640_quant_tflite_edgetpu_1',
#  'yolov8s_relu6_car--640x640_float_openvino_cpu_1',
#  'yolov8s_relu6_car--640x640_float_tflite_cpu_1',
#  'yolov8s_relu6_car--640x640_quant_tflite_cpu_1',
#  'yolov8s_relu6_car--640x640_quant_tflite_edgetpu_1',
#  'yolov8s_relu6_coco--640x640_float_openvino_cpu_1',
#  'yolov8s_relu6_coco--640x640_float_tflite_cpu_1',
#  'yolov8s_relu6_coco--640x640_quant_tflite_cpu_1',
#  'yolov8s_relu6_coco--640x640_quant_tflite_edgetpu_1',
#  'yolov8s_relu6_face--640x640_float_openvino_cpu_1',
#  'yolov8s_relu6_face--640x640_float_tflite_cpu_1',
#  'yolov8s_relu6_face--640x640_quant_tflite_cpu_1',
#  'yolov8s_relu6_face--640x640_quant_tflite_edgetpu_1',
#  'yolov8s_relu6_hand--640x640_float_openvino_cpu_1',
#  'yolov8s_relu6_hand--640x640_float_tflite_cpu_1',
#  'yolov8s_relu6_hand--640x640_quant_tflite_cpu_1',
#  'yolov8s_relu6_hand--640x640_quant_tflite_edgetpu_1',
#  'yolov8s_relu6_lp--640x640_float_openvino_cpu_1',
#  'yolov8s_relu6_lp--640x640_float_tflite_cpu_1',
#  'yolov8s_relu6_lp--640x640_quant_tflite_cpu_1',
#  'yolov8s_relu6_lp--640x640_quant_tflite_edgetpu_1',
#  'yolov8s_silu_car--640x640_float_openvino_cpu_1',
#  'yolov8s_silu_car--640x640_float_tflite_cpu_1',
#  'yolov8s_silu_car--640x640_quant_tflite_cpu_1',
#  'yolov8s_silu_car--640x640_quant_tflite_edgetpu_1',
#  'yolov8s_silu_coco--640x640_float_openvino_cpu_1',
#  'yolov8s_silu_coco--640x640_float_tflite_cpu_1',
#  'yolov8s_silu_coco--640x640_quant_tflite_cpu_1',
#  'yolov8s_silu_coco--640x640_quant_tflite_edgetpu_1',
#  'yolov8s_silu_face--640x640_float_openvino_cpu_1',
#  'yolov8s_silu_face--640x640_float_tflite_cpu_1',
#  'yolov8s_silu_face--640x640_quant_tflite_cpu_1',
#  'yolov8s_silu_face--640x640_quant_tflite_edgetpu_1',
#  'yolov8s_silu_hand--640x640_float_openvino_cpu_1',
#  'yolov8s_silu_hand--640x640_float_tflite_cpu_1',
#  'yolov8s_silu_hand--640x640_quant_tflite_cpu_1',
#  'yolov8s_silu_hand--640x640_quant_tflite_edgetpu_1',
#  'yolov8s_silu_lp--640x640_float_openvino_cpu_1',
#  'yolov8s_silu_lp--640x640_float_tflite_cpu_1',
#  'yolov8s_silu_lp--640x640_quant_tflite_cpu_1',
#  'yolov8s_silu_lp--640x640_quant_tflite_edgetpu_1']
